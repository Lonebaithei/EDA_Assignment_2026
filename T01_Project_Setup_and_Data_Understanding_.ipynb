# %% [markdown]
# <a href="https://colab.research.google.com/github/Lonebaithei/EDA_Assignment_2026/blob/main/T01_Project_Setup_and_Data_Understanding_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib . pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# List contents of your Drive
print("Contents of My Drive:")
print(os.listdir('/content/drive/MyDrive/Colab_Notebooks/ADA2026_Instacart_Project/data/raw/Instacart/archive(1)'))
# Out:
# Contents of My Drive:
# ['Copy of orders.csv', 'aisles.csv', 'departments.csv', 'order_products__prior.csv', 'order_products__train.csv', 'products.csv', 'orders.csv']

# %%
# Replace this path with the actual path you found
orders = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/ADA2026_Instacart_Project/data/raw/Instacart/archive(1)/orders.csv')
products = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/ADA2026_Instacart_Project/data/raw/Instacart/archive(1)/products.csv')
order_products = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/ADA2026_Instacart_Project/data/raw/Instacart/archive(1)/order_products__prior.csv')

# %% [markdown]
# Step 6;Inspecting tables

# %%
# orders table
orders.head()
orders.info()
orders.shape

# %%
# products table
products.head()
products.info()
products.shape

# %%
# order_products table
order_products.head()
order_products.info()
order_products.shape

# %% [markdown]
# Step 7;Check Missing Values

# %%
# orders table
orders.isna().sum().sort_values(ascending=False)

# %%
# products table
products.isna().sum().sort_values(ascending=False)

# %%
# orders_products table
order_products.isna().sum().sort_values(ascending=False)

# %% [markdown]
# Step 8;Data Dictionary

# %%
# Create a list of dictionaries, each representing one variable
data_dict = [
    {"Table": "orders", "Column": "order_id",
     "Meaning": "Unique identifier for each order",
     "Data Type": "int64",
     "Notes": "Primary key of the orders table."},

    {"Table": "orders", "Column": "user_id",
     "Meaning": "Identifier for the customer who placed the order",
     "Data Type": "int64",
     "Notes": "Can be used to link multiple orders to the same customer."},

    {"Table": "orders", "Column": "eval_set",
     "Meaning": "Indicates which evaluation set the order belongs to",
     "Data Type": "object",
     "Notes": "Values: ‘prior’, ‘train’, ‘test’."},

    {"Table": "orders", "Column": "order_number",
     "Meaning": "Sequential number showing the order sequence for the user",
     "Data Type": "int64",
     "Notes": "Starts at 1 for the user’s first order."},

    {"Table": "orders", "Column": "order_dow",
     "Meaning": "Day of week when the order was placed",
     "Data Type": "int64",
     "Notes": "0 = Sunday, 1 = Monday, …, 6 = Saturday."},

    {"Table": "orders", "Column": "order_hour_of_day",
     "Meaning": "Hour of day when the order was placed",
     "Data Type": "int64",
     "Notes": "Ranges from 0 to 23."},

    {"Table": "orders", "Column": "days_since_prior_order",
     "Meaning": "Number of days since the user’s previous order",
     "Data Type": "float64",
     "Notes": "Missing (NaN) for first orders; otherwise a positive number."},

    {"Table": "products", "Column": "product_id",
     "Meaning": "Unique identifier for each product",
     "Data Type": "int64",
     "Notes": "Primary key of the products table."},

    {"Table": "products", "Column": "product_name",
     "Meaning": "Name of the product",
     "Data Type": "object",
     "Notes": "All 49,688 entries are non‑null."},

    {"Table": "products", "Column": "aisle_id",
     "Meaning": "Identifier for the aisle where the product is located",
     "Data Type": "int64",
     "Notes": "Foreign key to an aisles table (if available)."},

    {"Table": "products", "Column": "department_id",
     "Meaning": "Identifier for the department",
     "Data Type": "int64",
     "Notes": "Foreign key to a departments table (if available)."},

    {"Table": "order_products", "Column": "order_id",
     "Meaning": "Identifier for the order (links to orders)",
     "Data Type": "int64",
     "Notes": "Part of composite key with product_id."},

    {"Table": "order_products", "Column": "product_id",
     "Meaning": "Identifier for the product (links to products)",
     "Data Type": "int64",
     "Notes": "Part of composite key with order_id."},

    {"Table": "order_products", "Column": "add_to_cart_order",
     "Meaning": "Sequence number indicating when the product was added to the cart",
     "Data Type": "int64",
     "Notes": "Order within the cart; 1 = first item added."},

    {"Table": "order_products", "Column": "reordered",
     "Meaning": "Whether the customer has ordered this product before",
     "Data Type": "int64",
     "Notes": "1 = yes, 0 = no."}
]

# Convert to DataFrame for a clean display
df_data_dictionary = pd.DataFrame(data_dict)

# Show the dictionary
df_data_dictionary
# Out:
#              Table                  Column  \
# 0           orders                order_id
# 1           orders                 user_id
# 2           orders                eval_set
# 3           orders            order_number
# 4           orders               order_dow
# 5           orders       order_hour_of_day
# 6           orders  days_since_prior_order
# 7         products              product_id
# 8         products            product_name
# 9         products                aisle_id
# 10        products           department_id
# 11  order_products                order_id
# 12  order_products              product_id
# 13  order_products       add_to_cart_order
# 14  order_products               reordered
#
#                                               Meaning Data Type  \
# 0                    Unique identifier for each order     int64
# 1    Identifier for the customer who placed the order     int64
# 2   Indicates which evaluation set the order belon...    object
# ...

# %% [markdown]
# Save interim Copies

# %%
orders.to_csv('/content/drive/MyDrive/Colab_Notebooks/ADA2026_Instacart_Project/data/raw/Instacart/archive(1)/orders.csv', index=False)
products.to_csv('/content/drive/MyDrive/Colab_Notebooks/ADA2026_Instacart_Project/data/raw/Instacart/archive(1)/products.csv', index=False)
order_products.to_csv('/content/drive/MyDrive/Colab_Notebooks/ADA2026_Instacart_Project/data/raw/Instacart/archive(1)/order_products__prior.csv', index=False)

# %% [markdown]
# Reflection
#
# This dataset represents an online grocery retail business. Customers place digital orders, and products are organised by department and aisle.
#
# The dataset could support decisions such as:
# - Product recommendation systems
# - Inventory planning
# - Customer retention strategies
# - Basket analysis for cross-selling
# - Demand forecasting
